# %% [markdown]
# # PatchSim

# %%
import pandas as pd
import patchsim as sim
import numpy as np

# %% [markdown]
# ### cfg.txt - Configuraciones

# %%
f = open("files/cfg.txt", "w")
f.write("""PatchFile=files/pop.txt
NetworkFile=files/net.txt
NetworkType=Static

ExposureRate=0.65
InfectionRate=0.67
RecoveryRate=0.4
WaningRate=0.03

SymptomaticProbability=0.2
AsymptomaticReduction=0.5
PresymptomaticReduction=0.5

ScalingFactor=0.01

SeedFile=files/seeds.txt
VaxFile=files/vaxs.txt
VaxDelay=0
VaxEfficacy=0

StartDate=1
Duration=400

LoadState=False
SaveState=False

OutputFile=resultados.out
OutputFormat=Whole
LogFile=proceso.log""")
f.close()

# %% [markdown]
# ### pop.txt - path_df - Tamaño de poblaciones

# %%
localidades = pd.read_csv("files/info_local_2020.csv")

df = pd.DataFrame( {"id_localidades":localidades["local_id"].values, 
                    "poblacion":localidades["PopCDR"].values})

df.to_csv("files/pop.txt", header = False, index = False, sep=' ')
df.head()

localidades.sort("")
# Out:
#     local_id           Localidad  PopCDR       Pop2020    Area
# 0          1             Usaquén  369936  7.699367e+05   65.31
# 1          2           Chapinero  152168  2.329447e+05   38.15
# 2          3            Santa Fe   93928  1.228405e+05   45.17
# 3          4       San Cristóbal  257646  6.432207e+05   49.09
# 4          5                Usme  230318  5.369947e+05  215.06
# 5          6          Tunjuelito  124375  2.686865e+05    9.91
# 6          7                Bosa  458427  1.402672e+06   23.93
# 7          8             Kennedy  730237  3.136487e+06   38.59
# 8          9            Fontibón  272242  8.223408e+05   33.28
# 9         10            Engativá  617260  1.387887e+06   35.88
# 10        11                Suba  865749  2.114909e+06  100.56
# 11        12      Barrios Unidos  169295  4.379607e+05   11.90
# 12        13         Teusaquillo  117041  2.454681e+05   14.19
# 13        14        Los Mártires   73041  1.864865e+05    6.51
# 14        15      Antonio Nariño   76972  1.948473e+05    4.88
# 15        16       Puente Aranda  158021  3.675129e+05   17.31
# 16        17       La Candelaria   19142  3.588982e+04    2.06
# 17        18  Rafael Uribe Uribe  265916  5.456436e+05   13.83
# 18        19      Ciudad Bolívar  498044  1.214821e+06  130.00

# %% [markdown]
# ### net.txt - Theta - Matriz de viajes

# %%
redes = pd.read_csv("files/cdr_od_loc.csv")

df = pd.DataFrame( {"origen":redes["o_loc"].values, 
                    "destino":redes["d_loc"].values, 
                    "dia":np.zeros(len(redes), dtype=int),
                    "hbw":redes["hbw"].values})

df.to_csv("files/net.txt", header = False, index = False, sep=' ')
df.head()
# Out:
#    origen  destino  dia            hbw
# 0       1        1    0  247173.641026
# 1       1        2    0   36749.435897
# 2       1        3    0    4919.897436
# 3       1        4    0   17711.692308
# 4       1        5    0   13177.128205

# %% [markdown]
# ### seeds.txt - Seed - Primeros infectados

# %%
# Semillas: 10 primeros dias
casos = pd.read_csv("files/osb_enftransm-covid-19_17042021.csv", nrows=732872, encoding='latin-1', delimiter=";")
casos["FECHA_DIAGNOSTICO"] = pd.to_datetime(casos["FECHA_DIAGNOSTICO"], format="%d/%m/%Y")  # Fecha diagnosticado to DateTime
dia1 = casos["FECHA_DIAGNOSTICO"].min()  # Primer caso de covid en Bogotá
print(dia1.date())  # 6 de marzo de 2020 -- Dia 1
dias = casos["FECHA_DIAGNOSTICO"] - dia1 # Resta fechas - dia 1
casos["dias"] = dias.dt.days+1  # To int.
casos = casos.rename(columns={"LOCALIDAD_ASIS": 'Localidad'}) 
datos = pd.merge(casos, localidades, on='Localidad')  # Uniendo datos by localidades.
group = datos.groupby(['dias', 'local_id']).size().reset_index(name='numero de casos')  
df = group[group["dias"]<=10]  # Semillas: Cantidad de infectados en los primeros 10 dias para cada localidad.
df.to_csv("files/seeds.txt", header = False, index = False, sep=' ')
df.head()
# Out:
# 2020-03-06
#    dias  local_id  numero de casos
# 0     1         1                1
# 1     5        10                2
# 2     7         8                1
# 3     7         9                1
# 4     8         2                1

# %% [markdown]
# ### vaxs.txt - Vacunas - Primeros vacunados

# %%
# No hace nada aqui. En el código patchsim vaxs está comentado, sin embargo necesita recibir la entrada.
Id = localidades["local_id"].values
df = pd.DataFrame( {"dias": np.zeros(len(Id), dtype=int),
                    "Id": Id,
                    "vacunados":np.zeros(len(Id), dtype=int)}) 
df.to_csv("files/vaxs.txt", header = False, index = False, sep=' ')
df.head(5)
# Out:
#    dias  Id  vacunados
# 0     0   1          0
# 1     0   2          0
# 2     0   3          0
# 3     0   4          0
# 4     0   5          0

# %% [markdown]
# ### Llamando función PatchSim

# %%
configs = sim.read_config('files/cfg.txt')
sim.run_disease_simulation(configs, write_epi=True)
# Out:
# 624216

# %%
import matplotlib.pyplot as plt
Infected = np.loadtxt("resultados.out")
print(Infected)
for i in Infected:
    plt.plot(i[1:])
# Out:
# [[  1.   0. 578. ...  97.  97.  97.]
#  [ 10.   0. 167. ... 161. 161. 161.]
#  [ 11.   0. 415. ... 226. 226. 226.]
#  ...
#  [  7.   0. 121. ... 120. 120. 120.]
#  [  8.   0. 171. ... 191. 191. 191.]
#  [  9.   0.  26. ...  71.  71.  71.]]
